# %%
import cv2
import numpy as np

# %%
def nothing(x):
    pass

# %%
bright = cv2.imread('cube1.jpg')
dark = cv2.imread('cube8.jpg')

# %%
cv2.imshow("original bright", bright)
cv2.imshow("original dark", dark)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#python 
brightHSV = cv2.cvtColor(bright, cv2.COLOR_BGR2HSV)
darkHSV = cv2.cvtColor(dark, cv2.COLOR_BGR2HSV)

brightYCB = cv2.cvtColor(bright, cv2.COLOR_BGR2YCrCb)
darkYCB = cv2.cvtColor(dark, cv2.COLOR_BGR2YCrCb)

brightLAB = cv2.cvtColor(bright, cv2.COLOR_BGR2LAB)
darkLAB = cv2.cvtColor(dark, cv2.COLOR_BGR2LAB)

# %%
bgr = [40, 158, 16]
thresh = 40
 
minBGR = np.array([bgr[0] - thresh, bgr[1] - thresh, bgr[2] - thresh])
maxBGR = np.array([bgr[0] + thresh, bgr[1] + thresh, bgr[2] + thresh])

cv2.createTrackbar('RGB_R_Min', 'colorspace', 0, 255, nothing)
cv2.createTrackbar('RGB_R_Max', 'colorspace', 0, 255, nothing)

cv2.createTrackbar('RGB_G_Min', 'colorspace', 0, 255, nothing)
cv2.createTrackbar('RGB_G_Max', 'colorspace', 0, 255, nothing)

cv2.createTrackbar('RGB_B_Min', 'colorspace', 0, 255, nothing)
cv2.createTrackbar('RGB_B_Max', 'colorspace', 0, 255, nothing)

maskBGR = cv2.inRange(bright,minBGR,maxBGR)
resultBGR = cv2.bitwise_and(bright, bright, mask = maskBGR)
 
#convert 1D array to 3D, then convert it to HSV and take the first element 
# this will be same as shown in the above figure [65, 229, 158]
hsv = cv2.cvtColor( np.uint8([[bgr]] ), cv2.COLOR_BGR2HSV)[0][0]
 
minHSV = np.array([hsv[0] - thresh, hsv[1] - thresh, hsv[2] - thresh])
maxHSV = np.array([hsv[0] + thresh, hsv[1] + thresh, hsv[2] + thresh])
 
maskHSV = cv2.inRange(brightHSV, minHSV, maxHSV)
resultHSV = cv2.bitwise_and(brightHSV, brightHSV, mask = maskHSV)
 
#convert 1D array to 3D, then convert it to YCrCb and take the first element 
ycb = cv2.cvtColor( np.uint8([[bgr]] ), cv2.COLOR_BGR2YCrCb)[0][0]
 
minYCB = np.array([ycb[0] - thresh, ycb[1] - thresh, ycb[2] - thresh])
maxYCB = np.array([ycb[0] + thresh, ycb[1] + thresh, ycb[2] + thresh])
 
maskYCB = cv2.inRange(brightYCB, minYCB, maxYCB)
resultYCB = cv2.bitwise_and(brightYCB, brightYCB, mask = maskYCB)
 
#convert 1D array to 3D, then convert it to LAB and take the first element 
lab = cv2.cvtColor( np.uint8([[bgr]] ), cv2.COLOR_BGR2LAB)[0][0]
 
minLAB = np.array([lab[0] - thresh, lab[1] - thresh, lab[2] - thresh])
maxLAB = np.array([lab[0] + thresh, lab[1] + thresh, lab[2] + thresh])
 
maskLAB = cv2.inRange(brightLAB, minLAB, maxLAB)
resultLAB = cv2.bitwise_and(brightLAB, brightLAB, mask = maskLAB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-cdb6ff615197> in <module>()
#       5 maxBGR = np.array([bgr[0] + thresh, bgr[1] + thresh, bgr[2] + thresh])
#       6
# ----> 7 cv2.createTrackbar('RGB_R_Min', 'colorspace', 0, 255, nothing)
#       8 cv2.createTrackbar('RGB_R_Max', 'colorspace', 0, 255, nothing)
#       9
#
# error: /home/thomas/opencv-3.3.0/modules/highgui/src/window_QT.cpp:591: error: (-27) NULL guiReceiver (please create a window) in function cvCreateTrackbar2

# %%
#RGB
nameWindow = 'colorspace'
cv2.namedWindow(nameWindow)

cv2.createTrackbar('RGB_R_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('RGB_R_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('RGB_G_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('RGB_G_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('RGB_B_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('RGB_B_Max', nameWindow, 0, 255, nothing)

while(1):
    rgb_r_min = cv2.getTrackbarPos('RGB_R_Min', nameWindow)
    rgb_r_max = cv2.getTrackbarPos('RGB_R_Max', nameWindow)

    rgb_g_min = cv2.getTrackbarPos('RGB_G_Min', nameWindow)
    rgb_g_max = cv2.getTrackbarPos('RGB_G_Max', nameWindow)

    rgb_b_min = cv2.getTrackbarPos('RGB_B_Min', nameWindow)
    rgb_b_max = cv2.getTrackbarPos('RGB_B_Max', nameWindow)


    minBGR = np.array([rgb_r_min, rgb_g_min, rgb_b_min])
    maxBGR = np.array([rgb_r_max, rgb_g_max, rgb_b_max])

    maskBGR = cv2.inRange(bright, minBGR, maxBGR)
    resultBGR = cv2.bitwise_and(bright, bright, mask = maskBGR)
    
    cv2.imshow("original bright", bright)
    cv2.imshow("Result BGR", resultBGR)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break
    
cv2.destroyAllWindows()

# %%
#HSV
brightHSV = cv2.cvtColor(bright, cv2.COLOR_BGR2HSV)
darkHSV = cv2.cvtColor(dark, cv2.COLOR_BGR2HSV)

bgr = [40, 158, 16]
hsv = cv2.cvtColor( np.uint8([[bgr]] ), cv2.COLOR_BGR2HSV)[0][0]

nameWindow = 'colorspace'
cv2.namedWindow(nameWindow)

cv2.createTrackbar('HSV_H_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('HSV_H_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('HSV_S_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('HSV_S_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('HSV_V_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('HSV_V_Max', nameWindow, 0, 255, nothing)

while(1):
    hsv_h_min = cv2.getTrackbarPos('HSV_H_Min', nameWindow)
    hsv_h_max = cv2.getTrackbarPos('HSV_H_Max', nameWindow)

    hsv_s_min = cv2.getTrackbarPos('HSV_S_Min', nameWindow)
    hsv_s_max = cv2.getTrackbarPos('HSV_S_Max', nameWindow)

    hsv_v_min = cv2.getTrackbarPos('HSV_V_Min', nameWindow)
    hsv_v_max = cv2.getTrackbarPos('HSV_V_Max', nameWindow)

    minHSV = np.array([hsv_h_min, hsv_s_min, hsv_v_min])
    maxHSV = np.array([hsv_h_max, hsv_s_max, hsv_v_max])
    
    maskHSV = cv2.inRange(brightHSV, minHSV, maxHSV)
    resultHSV = cv2.bitwise_and(brightHSV, brightHSV, mask = maskHSV)
    
    cv2.imshow("original bright", bright)
    cv2.imshow("Result HSV", resultHSV)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break
    
cv2.destroyAllWindows()

# %%
#ycb

brightYCB = cv2.cvtColor(bright, cv2.COLOR_BGR2YCrCb)
darkYCB = cv2.cvtColor(dark, cv2.COLOR_BGR2YCrCb)

nameWindow = 'colorspace'
cv2.namedWindow(nameWindow)

cv2.createTrackbar('YCB_Y_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('YCB_Y_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('YCB_C_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('YCB_C_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('YCB_B_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('YCB_B_Max', nameWindow, 0, 255, nothing)

while(1):
    ycb_y_min = cv2.getTrackbarPos('YCB_Y_Min', nameWindow)
    ycb_y_max = cv2.getTrackbarPos('YCB_Y_Max', nameWindow)

    ycb_c_min = cv2.getTrackbarPos('YCB_C_Min', nameWindow)
    ycb_c_max = cv2.getTrackbarPos('YCB_C_Max', nameWindow)

    ycb_b_min = cv2.getTrackbarPos('YCB_B_Min', nameWindow)
    ycb_b_max = cv2.getTrackbarPos('YCB_B_Max', nameWindow)

    minYCB = np.array([ycb_y_min, ycb_c_min, ycb_b_min])
    maxYCB = np.array([ycb_y_max, ycb_c_max, ycb_b_max])
    
    maskYCB = cv2.inRange(brightYCB, minYCB, maxYCB)
    resultYCB = cv2.bitwise_and(brightYCB, brightYCB, mask = maskYCB)
    
    cv2.imshow("original bright", bright)
    cv2.imshow("Result YCB", resultYCB)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break
    
cv2.destroyAllWindows()

# %%
#LAB
brightLAB = cv2.cvtColor(bright, cv2.COLOR_BGR2LAB)
darkLAB = cv2.cvtColor(dark, cv2.COLOR_BGR2LAB)

nameWindow = 'colorspace'
cv2.namedWindow(nameWindow)

cv2.createTrackbar('LAB_L_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('LAB_L_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('LAB_A_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('LAB_A_Max', nameWindow, 0, 255, nothing)

cv2.createTrackbar('LAB_B_Min', nameWindow, 0, 255, nothing)
cv2.createTrackbar('LAB_B_Max', nameWindow, 0, 255, nothing)

while(1):
    lab_l_min = cv2.getTrackbarPos('LAB_L_Min', nameWindow)
    lab_l_max = cv2.getTrackbarPos('LAB_L_Max', nameWindow)

    lab_a_min = cv2.getTrackbarPos('LAB_A_Min', nameWindow)
    lab_a_max = cv2.getTrackbarPos('LAB_A_Max', nameWindow)

    lab_b_min = cv2.getTrackbarPos('LAB_B_Min', nameWindow)
    lab_b_max = cv2.getTrackbarPos('LAB_B_Max', nameWindow)

    minLAB = np.array([lab_l_min, lab_a_min, lab_b_min])
    maxLAB = np.array([lab_l_max, lab_a_max, lab_b_max])
    
    maskLAB = cv2.inRange(brightLAB, minLAB, maxLAB)
    resultLAB = cv2.bitwise_and(brightLAB, brightLAB, mask = maskLAB)
    
    cv2.imshow("original bright", bright)
    cv2.imshow("Result LAB", resultLAB)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break
    
cv2.destroyAllWindows()
